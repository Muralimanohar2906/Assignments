# %%
# Check Python version
import sys
print("Python version:", sys.version)
 
# Check installed modules
help("modules")
 
# Quick version compare
if sys.version_info >= (3, 10):
    print("✅ You’re on a modern Python version!")
else:
    print("⚠️ Consider Upgrading Python.")
# Out:
# Python version: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
#
# Please wait a moment while I gather a list of all available modules...
#
# IPython             adodbapi            marshal             sysconfig
# __future__          afxres              math                tabnanny
# __hello__           antigravity         matplotlib_inline   tarfile
# __phello__          argparse            mimetypes           tempfile
# _abc                array               mmap                textwrap
# _aix_support        ast                 mmapfile            this
# _android_support    asttokens           mmsystem            threading
# _apple_support      asyncio             modulefinder        time
# _ast                atexit              msvcrt              timeit
# _asyncio            base64              multiprocessing     timer
# _bisect             bdb                 nest_asyncio        tkinter
# _blake2             binascii            netbios             token
# _bz2                bisect              netrc               tokenize
# _codecs             builtins            nt                  tomllib
# _codecs_cn          bz2                 ntpath              tornado
# _codecs_hk          cProfile            ntsecuritycon       trace
# _codecs_iso2022     calendar            nturl2path          traceback
# _codecs_jp          cmath               numbers             tracemalloc
# _codecs_kr          cmd                 odbc                traitlets
# _codecs_tw          code                opcode              tty
# _collections        codecs              operator            turtle
# _collections_abc    codeop              optparse            turtledemo
# _colorize           collections         os                  types
# _compat_pickle      colorama            packaging           typing
# _compression        colorsys            parso               unicodedata
# _contextvars        comm                pathlib             unittest
# _csv                commctrl            pdb                 urllib
# _ctypes             compileall          perfmon             uuid
# _datetime           concurrent          pickle              venv
# _decimal            configparser        pickletools         warnings
# _elementtree        contextlib          pip                 wave
# _functools          contextvars         pkgutil             wcwidth
# _hashlib            copy                platform            weakref
# _heapq              copyreg             platformdirs        webbrowser
# _imp                csv                 plistlib            win2kras
# _interpchannels     ctypes              poplib              win32api
# _interpqueues       curses              posixpath           win32clipboard
# _interpreters       dataclasses         pprint              win32com
# _io                 datetime            profile             win32con
# _ios_support        dateutil            prompt_toolkit      win32console
# _json               dbm                 pstats              win32cred
# _locale             dde                 psutil              win32crypt
# _lsprof             debugpy             pty                 win32cryptcon
# _lzma               decimal             pure_eval           win32event
# _markupbase         decorator           py_compile          win32evtlog
# _md5                difflib             pyclbr              win32evtlogutil
# _multibytecodec     dis                 pydoc               win32file
# _multiprocessing    doctest             pydoc_data          win32gui
# _opcode             email               pyexpat             win32gui_struct
# _opcode_metadata    encodings           pygments            win32help
# _operator           ensurepip           pythoncom           win32inet
# _osx_support        enum                pywin               win32inetcon
# _overlapped         errno               pywin32_bootstrap   win32job
# _pickle             executing           pywin32_testutil    win32lz
# _py_abc             faulthandler        pywintypes          win32net
# _pydatetime         filecmp             queue               win32netcon
# _pydecimal          fileinput           quopri              win32pdh
# _pyio               fnmatch             random              win32pdhquery
# _pylong             fractions           rasutil             win32pdhutil
# _pyrepl             ftplib              re                  win32pipe
# _queue              functools           regcheck            win32print
# _random             gc                  regutil             win32process
# _sha1               genericpath         reprlib             win32profile
# _sha2               getopt              rlcompleter         win32ras
# _sha3               getpass             runpy               win32rcparser
# _signal             gettext             sched               win32security
# _sitebuiltins       glob                secrets             win32service
# _socket             graphlib            select              win32serviceutil
# _sqlite3            gzip                selectors           win32timezone
# _sre                hashlib             servicemanager      win32trace
# _ssl                heapq               shelve              win32traceutil
# _stat               hmac                shlex               win32transaction
# _statistics         html                shutil              win32ts
# _string             http                signal              win32ui
# _strptime           idlelib             site                win32uiole
# _struct             imaplib             six                 win32verstamp
# _suggestions        importlib           smtplib             win32wnet
# _symtable           inspect             socket              winerror
# _sysconfig          io                  socketserver        winioctlcon
# _thread             ipaddress           sqlite3             winnt
# _threading_local    ipykernel           sre_compile         winperf
# _tkinter            ipykernel_launcher  sre_constants       winreg
# _tokenize           ipython_pygments_lexers sre_parse           winsound
# _tracemalloc        isapi               ssl                 winxpgui
# _typing             itertools           sspi                winxptheme
# _uuid               jedi                sspicon             wsgiref
# _warnings           json                stack_data          xml
# _weakref            jupyter             start_pythonwin     xmlrpc
# _weakrefset         jupyter_client      stat                xxsubtype
# _win32sysloader     jupyter_core        statistics          zipapp
# _win32verstamp_pywin32ctypes keyword             string              zipfile
# _winapi             linecache           stringprep          zipimport
# _winxptheme         locale              struct              zlib
# _wmi                logging             subprocess          zmq
# _zoneinfo           lzma                symtable            zoneinfo
# abc                 mailbox             sys
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
#
# ✅ You’re on a modern Python version!
